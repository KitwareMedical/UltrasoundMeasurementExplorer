# %%
import pyrealsense2 as rs

# %%
# First import the library
import pyrealsense2 as rs
import os
import scipy

from scipy.spatial.transform import Rotation

import urllib.request
import json      
import time
def postJson(euler):


    body = euler + [time.time()]
    
    print(body)

    myurl = "http://localhost/transform"
    req = urllib.request.Request(myurl)
    req.add_header('Content-Type', 'application/json; charset=utf-8')
    jsondata = json.dumps(body)
    jsondataasbytes = jsondata.encode('utf-8')   # needs to be bytes
    req.add_header('Content-Length', len(jsondataasbytes))
    print (jsondataasbytes)
    response = urllib.request.urlopen(req, jsondataasbytes)


# Declare RealSense pipeline, encapsulating the actual device and sensors
pipe = rs.pipeline()

# Build config object and request pose data
cfg = rs.config()
cfg.enable_stream(rs.stream.pose)

# Start streaming with requested config
pipe.start(cfg)
exit
try:
    for _ in range(15090):
        # Wait for the next set of frames from the camera
        frames = pipe.wait_for_frames()

        # Fetch pose frame
        pose = frames.get_pose_frame()
        if pose:
            # Print some of the pose data to the terminal
            data = pose.get_pose_data()
            
            rot = data.rotation

            euler = Rotation.from_quat([rot.x, rot.y, rot.z, rot.w]).as_euler("xzy", degrees=True)
            
            os.write(1, "Rotation: {}\r".format(
                euler
            ).encode())
            postJson([euler[2], euler[0], euler[1]])

finally:
    os.write(1, "\n".encode())
    pipe.stop()
# Out:
# [-0.02852236112613887, -2.348039573819786, -0.9585978990571277, 1565294413.2240202]
# b'[-0.02852236112613887, -2.348039573819786, -0.9585978990571277, 1565294413.2240202]'
# [-0.03953061141387488, -2.351912028624951, -0.9583197016935013, 1565294413.2280085]
# b'[-0.03953061141387488, -2.351912028624951, -0.9583197016935013, 1565294413.2280085]'
# [-0.06805485883371601, -2.323344772369715, -0.9748230809264178, 1565294413.2310004]
# b'[-0.06805485883371601, -2.323344772369715, -0.9748230809264178, 1565294413.2310004]'
# [-0.06954257039168596, -2.323008717562391, -0.9742187452491536, 1565294413.2349946]
# b'[-0.06954257039168596, -2.323008717562391, -0.9742187452491536, 1565294413.2349946]'
# [-0.07024457492606509, -2.322022867648054, -0.9743613180475376, 1565294413.240978]
# b'[-0.07024457492606509, -2.322022867648054, -0.9743613180475376, 1565294413.240978]'
# [-0.07206790572192666, -2.3223587807366544, -0.9734780336452331, 1565294413.2449677]
# ...

# %%
n = data.rotation

# %%
Rotation.from_quat([rot.x, rot.y, rot.z, rot.w]).as_euler("yzx", degrees=True)
# Out:
# array([156.78192343,   1.03413288,  78.74443359])

# %%
json.dumps([])
# Out:
# '[]'

# %%
# First import the library
import pyrealsense2 as rs
import os
import scipy

from scipy.spatial.transform import Rotation

import urllib.request
import json      
import time
def postJson(euler):


    body = euler + [time.time()]
    
    print(body)

    myurl = "http://localhost/transform"
    req = urllib.request.Request(myurl)
    req.add_header('Content-Type', 'application/json; charset=utf-8')
    jsondata = json.dumps(body)
    jsondataasbytes = jsondata.encode('utf-8')   # needs to be bytes
    req.add_header('Content-Length', len(jsondataasbytes))
    print (jsondataasbytes)
    response = urllib.request.urlopen(req, jsondataasbytes)


# Declare RealSense pipeline, encapsulating the actual device and sensors
pipe = rs.pipeline()

# Build config object and request pose data
cfg = rs.config()
cfg.enable_stream(rs.stream.pose)

# Start streaming with requested config
pipe.start(cfg)
exit
try:
    for _ in range(15090):
        # Wait for the next set of frames from the camera
        frames = pipe.wait_for_frames()

        # Fetch pose frame
        pose = frames.get_pose_frame()
        if pose:
            # Print some of the pose data to the terminal
            data = pose.get_pose_data()
            
            rot = data.rotation

            euler = Rotation.from_quat([rot.x, rot.y, rot.z, rot.w]).as_euler("xzy", degrees=True)
            
            os.write(1, "Rotation: {}\r".format(
                euler
            ).encode())
            postJson([euler[2], euler[0], euler[1]])

finally:
    os.write(1, "\n".encode())
    pipe.stop()
